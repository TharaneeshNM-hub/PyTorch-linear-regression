# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
# Sample data
x = torch.tensor([[1.0], [2.0], [3.0], [4.0]])
y = torch.tensor([[3.0], [5.0], [7.0], [9.0]])

# %%
# Linear model
model = nn.Linear(1, 1) # 1 input, 1 output

# %%
loss_fn = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(1000):
    y_pred = model(x)
    loss = loss_fn(y_pred, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        print(f'Epoch {epoch}, Loss: {loss.item():.4f}')
# Out:
# Epoch 0, Loss: 43.4197
# Epoch 100, Loss: 0.1174
# Epoch 200, Loss: 0.0644
# Epoch 300, Loss: 0.0354
# Epoch 400, Loss: 0.0194
# Epoch 500, Loss: 0.0107
# Epoch 600, Loss: 0.0059
# Epoch 700, Loss: 0.0032
# Epoch 800, Loss: 0.0018
# Epoch 900, Loss: 0.0010

# %%
with torch.no_grad():
  test = torch.tensor([[5.0]])
  prediction = model(test)
  print(f'prediction for x=5": {prediction.item():.2f}')
# Out:
# prediction for x=5": 11.04

# %%
import torch
import random

x = torch.tensor([[i] for i in range(1, 11)], dtype=torch.float32)
y = torch.tensor([[2*i + 1 + random.uniform(-1, 1)] for i in range(1, 11)], dtype=torch.float32)

# %%
w = model.weight.item()
b = model.bias.item()
print(f"Learned equation: y = {w:.2f}x + {b:.2f}")
# Out:
# Learned equation: y = 2.02x + 0.94
